-- %% [markdown]
-- # In class exercis 03
-- - nobel data

-- %%
CREATE CATALOG IF NOT EXISTS data2;
CREATE SCHEMA IF NOT EXISTS data2.nobel_prize;

--fully qualified name:catalog.schema.volume 
CREATE VOLUME IF NOT EXISTS data2.nobel_prize.raw_data;

list '/Volumes/data2/nobel_prize/raw_data'

-- %%
SHOW CATALOGS;

-- %%
SHOW SCHEMAS IN DATA2
